# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("cleaned_Dataset.csv")

# %%
df_new = pd.DataFrame(data = df, columns = ["anne_sektor","baba_sektor"])

# %%
df_new = df_new.replace(['0', '-'], 'Unknown')

# Or alternatively, use NaN and fill later:
# data = data.replace(['0', '-'], pd.NA)

# %%
df_new
# Out:
#        anne_sektor  baba_sektor
# 0          Unknown      Unknown
# 1             kamu      Unknown
# 2          Unknown      Unknown
# 3          Unknown         kamu
# 4          Unknown      Unknown
# ...            ...          ...
# 46063      Unknown        diger
# 46064      Unknown  ozel sektor
# 46065      Unknown  ozel sektor
# 46066      Unknown      Unknown
# 46067  ozel sektor         kamu
#
# [46068 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Apply label encoding
label_encoder = LabelEncoder()

# Encoding 'anne_sektor' and 'baba_sektor' columns
df_new['anne_sektor_encoded'] = label_encoder.fit_transform(df_new['anne_sektor'])
df_new['baba_sektor_encoded'] = label_encoder.fit_transform(df_new['baba_sektor'])

# %%
df_new = pd.get_dummies(df_new, columns=['anne_sektor', 'baba_sektor'], prefix=['anne', 'baba'], dummy_na=True)

# %%
df_new = df_new.drop(["anne_nan","baba_nan"],axis =1)
df_new
# Out:
#        anne_sektor_encoded  baba_sektor_encoded  anne_Unknown  anne_diger  \
# 0                        0                    0          True       False
# 1                        2                    0         False       False
# 2                        0                    0          True       False
# 3                        0                    2          True       False
# 4                        0                    0          True       False
# ...                    ...                  ...           ...         ...
# 46063                    0                    1          True       False
# 46064                    0                    3          True       False
# 46065                    0                    3          True       False
# 46066                    0                    0          True       False
# 46067                    3                    2         False       False
#
#        anne_kamu  anne_ozel sektor  baba_Unknown  baba_diger  baba_kamu  \
# 0          False             False          True       False      False
# 1           True             False          True       False      False
# 2          False             False          True       False      False
# 3          False             False         False       False       True
# 4          False             False          True       False      False
# ...          ...               ...           ...         ...        ...
# 46063      False             False         False        True      False
# 46064      False             False         False       False      False
# 46065      False             False         False       False      False
# 46066      False             False          True       False      False
# 46067      False              True         False       False       True
#
#        baba_ozel sektor
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 46063             False
# 46064              True
# 46065              True
# 46066             False
# 46067             False
#
# [46068 rows x 10 columns]

# %%
df=df.drop(["anne_sektor","baba_sektor"],axis =1)

# %%
cleanedData = pd.concat([df,df_new],axis = 1)
cleanedData
# Out:
#        basvuru_yili  degerlendirme_puani cinsiyet dogum_tarihi  \
# 0              2014                 52.0    erkek   1994-04-06
# 1              2014                 30.0    erkek   1993-06-11
# 2              2014                 40.0    erkek   1991-06-04
# 3              2014                 37.0    erkek   1992-04-14
# 4              2014                 24.0    erkek   1993-03-18
# ...             ...                  ...      ...          ...
# 46063          2022                  0.0    erkek   2002-03-26
# 46064          2022                  0.0    erkek   2003-12-11
# 46065          2022                  0.0    erkek   2003-06-18
# 46066          2022                  0.0    erkek   1999-10-23
# 46067          2022                  0.0    erkek   2000-11-17
#
#              dogum_yeri ikametgah_sehri                 universite_adi  \
# 0      altindag, ankara          ankara        ihsan dogramaci bilkent
# 1               uskudar        istanbul        ihsan dogramaci bilkent
# 2            diyarbakir        istanbul    istanbul sehir universitesi
# 3              istanbul        istanbul  istanbul ticaret universitesi
# 4              istanbul        istanbul      fatih sultan mehmet vakif
# ...                 ...             ...                            ...
# 46063           trabzon         trabzon           trabzon universitesi
# 46064             izmir           izmir       dokuz eylul universitesi
# 46065          istanbul        istanbul    istanbul aydin universitesi
# 46066            mersin          mersin  suleyman demirel universitesi
# 46067            samsun          samsun           karabuk universitesi
#
#       universite_turu  burslu_ise_burs_yuzdesi  burs_aliyor_mu?  ...  \
# 0                ozel                    100.0                1  ...
# 1                ozel                    100.0                0  ...
# 2                ozel                    100.0                1  ...
# 3                ozel                    100.0                1  ...
# 4                ozel                    100.0                1  ...
# ...               ...                      ...              ...  ...
# 46063          devlet                      0.0                0  ...
# 46064          devlet                      0.0                0  ...
# 46065            ozel                      0.0                1  ...
# 46066          devlet                      0.0                0  ...
# 46067          devlet                      0.0                0  ...
#
#       anne_sektor_encoded baba_sektor_encoded  anne_Unknown  anne_diger  \
# 0                       0                   0          True       False
# 1                       2                   0         False       False
# 2                       0                   0          True       False
# 3                       0                   2          True       False
# 4                       0                   0          True       False
# ...                   ...                 ...           ...         ...
# 46063                   0                   1          True       False
# 46064                   0                   3          True       False
# 46065                   0                   3          True       False
# 46066                   0                   0          True       False
# 46067                   3                   2         False       False
#
#       anne_kamu anne_ozel sektor baba_Unknown baba_diger baba_kamu  \
# 0         False            False         True      False     False
# 1          True            False         True      False     False
# 2         False            False         True      False     False
# 3         False            False        False      False      True
# 4         False            False         True      False     False
# ...         ...              ...          ...        ...       ...
# 46063     False            False        False       True     False
# 46064     False            False        False      False     False
# 46065     False            False        False      False     False
# 46066     False            False         True      False     False
# 46067     False             True        False      False      True
#
#       baba_ozel sektor
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 46063            False
# 46064             True
# 46065             True
# 46066            False
# 46067            False
#
# [46068 rows x 52 columns]

# %%
cleanedData['cinsiyet'] = cleanedData['cinsiyet'].map({'Erkek': 0, 'Kadin': 1 ,"Belirtmek istemiyorum":-1})

# %%
cleanedData
# Out:
#        basvuru_yili  degerlendirme_puani  cinsiyet dogum_tarihi  \
# 0              2014                 52.0       NaN   1994-04-06
# 1              2014                 30.0       NaN   1993-06-11
# 2              2014                 40.0       NaN   1991-06-04
# 3              2014                 37.0       NaN   1992-04-14
# 4              2014                 24.0       NaN   1993-03-18
# ...             ...                  ...       ...          ...
# 46063          2022                  0.0       NaN   2002-03-26
# 46064          2022                  0.0       NaN   2003-12-11
# 46065          2022                  0.0       NaN   2003-06-18
# 46066          2022                  0.0       NaN   1999-10-23
# 46067          2022                  0.0       NaN   2000-11-17
#
#              dogum_yeri ikametgah_sehri                 universite_adi  \
# 0      altindag, ankara          ankara        ihsan dogramaci bilkent
# 1               uskudar        istanbul        ihsan dogramaci bilkent
# 2            diyarbakir        istanbul    istanbul sehir universitesi
# 3              istanbul        istanbul  istanbul ticaret universitesi
# 4              istanbul        istanbul      fatih sultan mehmet vakif
# ...                 ...             ...                            ...
# 46063           trabzon         trabzon           trabzon universitesi
# 46064             izmir           izmir       dokuz eylul universitesi
# 46065          istanbul        istanbul    istanbul aydin universitesi
# 46066            mersin          mersin  suleyman demirel universitesi
# 46067            samsun          samsun           karabuk universitesi
#
#       universite_turu  burslu_ise_burs_yuzdesi  burs_aliyor_mu?  ...  \
# 0                ozel                    100.0                1  ...
# 1                ozel                    100.0                0  ...
# 2                ozel                    100.0                1  ...
# 3                ozel                    100.0                1  ...
# 4                ozel                    100.0                1  ...
# ...               ...                      ...              ...  ...
# 46063          devlet                      0.0                0  ...
# 46064          devlet                      0.0                0  ...
# 46065            ozel                      0.0                1  ...
# 46066          devlet                      0.0                0  ...
# 46067          devlet                      0.0                0  ...
#
#       anne_sektor_encoded baba_sektor_encoded  anne_Unknown  anne_diger  \
# 0                       0                   0          True       False
# 1                       2                   0         False       False
# 2                       0                   0          True       False
# 3                       0                   2          True       False
# 4                       0                   0          True       False
# ...                   ...                 ...           ...         ...
# 46063                   0                   1          True       False
# 46064                   0                   3          True       False
# 46065                   0                   3          True       False
# 46066                   0                   0          True       False
# 46067                   3                   2         False       False
#
#       anne_kamu anne_ozel sektor baba_Unknown baba_diger baba_kamu  \
# 0         False            False         True      False     False
# 1          True            False         True      False     False
# 2         False            False         True      False     False
# 3         False            False        False      False      True
# 4         False            False         True      False     False
# ...         ...              ...          ...        ...       ...
# 46063     False            False        False       True     False
# 46064     False            False        False      False     False
# 46065     False            False        False      False     False
# 46066     False            False         True      False     False
# 46067     False             True        False      False      True
#
#       baba_ozel sektor
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 46063            False
# 46064             True
# 46065             True
# 46066            False
# 46067            False
#
# [46068 rows x 52 columns]

# %%
cleanedData.to_csv("cleanedData.csv")

# %%
from datetime import datetime

# %%
cleanedData['dogum_tarihi'] = pd.to_datetime(cleanedData['dogum_tarihi'])

# Extract the year of birth
cleanedData['birth_year'] = cleanedData['dogum_tarihi'].dt.year
cleanedData['age'] = 2024 - cleanedData['birth_year']
cleanedData["age"]
# Out:
# 0        30
# 1        31
# 2        33
# 3        32
# 4        31
#          ..
# 46063    22
# 46064    21
# 46065    21
# 46066    25
# 46067    24
# Name: age, Length: 46068, dtype: int32

# %%
cleanedData = cleanedData.drop(["birth_year","dogum_tarihi"],axis =1)

# %%
cleanedData.to_csv("cleanedData.csv")

# %%
list = []
for columns in cleanedData:
    list.append(columns)
list
# Out:
# ['basvuru_yili',
#  'degerlendirme_puani',
#  'cinsiyet',
#  'dogum_yeri',
#  'ikametgah_sehri',
#  'universite_adi',
#  'universite_turu',
#  'burslu_ise_burs_yuzdesi',
#  'burs_aliyor_mu?',
#  'bolum',
#  'universite_kacinci_sinif',
#  'universite_not_ortalamasi',
#  'daha_once_baska_bir_universiteden_mezun_olmus',
#  'lise_adi',
#  'lise_adi_diger',
#  'lise_sehir',
#  'lise_turu',
#  'lise_bolumu',
#  'lise_bolum_diger',
#  'lise_mezuniyet_notu',
#  'baska_bir_kurumdan_burs_aliyor_mu?',
#  'burs_aldigi_baska_kurum',
#  'baska_kurumdan_aldigi_burs_miktari',
#  'anne_egitim_durumu',
#  'anne_calisma_durumu',
#  'baba_egitim_durumu',
#  'baba_calisma_durumu',
#  'kardes_sayisi',
#  'girisimcilik_kulupleri_tarzi_bir_kulube_uye_misiniz?',
#  'uye_oldugunuz_kulubun_ismi',
#  'profesyonel_bir_spor_daliyla_mesgul_musunuz?',
#  'spor_dalindaki_rolunuz_nedir?',
#  'aktif_olarak_bir_stk_uyesi_misiniz?',
#  "hangi_stk'nin_uyesisiniz?",
#  'stk_projesine_katildiniz_mi?',
#  'girisimcilikle_ilgili_deneyiminiz_var_mi?',
#  'girisimcilikle_ilgili_deneyiminizi_aciklayabilir_misiniz?',
#  'ingilizce_biliyor_musunuz?',
#  'ingilizce_seviyeniz?',
#  'daha_onceden_mezun_olunduysa,_mezun_olunan_universite',
#  'id',
#  'anne_sektor_encoded',
#  'baba_sektor_encoded',
#  'anne_Unknown',
#  'anne_diger',
#  'anne_kamu',
#  'anne_ozel sektor',
#  'baba_Unknown',
#  'baba_diger',
#  'baba_kamu',
#  'baba_ozel sektor',
#  'age']

# %%
cleanedData
# Out:
#        basvuru_yili  degerlendirme_puani  cinsiyet        dogum_yeri  \
# 0              2014                 52.0       NaN  altindag, ankara
# 1              2014                 30.0       NaN           uskudar
# 2              2014                 40.0       NaN        diyarbakir
# 3              2014                 37.0       NaN          istanbul
# 4              2014                 24.0       NaN          istanbul
# ...             ...                  ...       ...               ...
# 46063          2022                  0.0       NaN           trabzon
# 46064          2022                  0.0       NaN             izmir
# 46065          2022                  0.0       NaN          istanbul
# 46066          2022                  0.0       NaN            mersin
# 46067          2022                  0.0       NaN            samsun
#
#       ikametgah_sehri                 universite_adi universite_turu  \
# 0              ankara        ihsan dogramaci bilkent            ozel
# 1            istanbul        ihsan dogramaci bilkent            ozel
# 2            istanbul    istanbul sehir universitesi            ozel
# 3            istanbul  istanbul ticaret universitesi            ozel
# 4            istanbul      fatih sultan mehmet vakif            ozel
# ...               ...                            ...             ...
# 46063         trabzon           trabzon universitesi          devlet
# 46064           izmir       dokuz eylul universitesi          devlet
# 46065        istanbul    istanbul aydin universitesi            ozel
# 46066          mersin  suleyman demirel universitesi          devlet
# 46067          samsun           karabuk universitesi          devlet
#
#        burslu_ise_burs_yuzdesi  burs_aliyor_mu?  \
# 0                        100.0                1
# 1                        100.0                0
# 2                        100.0                1
# 3                        100.0                1
# 4                        100.0                1
# ...                        ...              ...
# 46063                      0.0                0
# 46064                      0.0                0
# 46065                      0.0                1
# 46066                      0.0                0
# 46067                      0.0                0
#
#                                   bolum  ... baba_sektor_encoded  \
# 0               bilgisayar muhendisligi  ...                   0
# 1      elektrik elektronik muhendisligi  ...                   0
# 2               bilgisayar muhendisligi  ...                   0
# 3                  bankacilik ve finans  ...                   2
# 4               bilgisayar muhendisligi  ...                   0
# ...                                 ...  ...                 ...
# 46063                             diger  ...                   1
# 46064                             diger  ...                   3
# 46065                          muhasebe  ...                   3
# 46066             otomotiv muhendisligi  ...                   0
# 46067                      sanat tarihi  ...                   2
#
#        anne_Unknown  anne_diger anne_kamu anne_ozel sektor baba_Unknown  \
# 0              True       False     False            False         True
# 1             False       False      True            False         True
# 2              True       False     False            False         True
# 3              True       False     False            False        False
# 4              True       False     False            False         True
# ...             ...         ...       ...              ...          ...
# 46063          True       False     False            False        False
# 46064          True       False     False            False        False
# 46065          True       False     False            False        False
# 46066          True       False     False            False         True
# 46067         False       False     False             True        False
#
#       baba_diger baba_kamu baba_ozel sektor age
# 0          False     False            False  30
# 1          False     False            False  31
# 2          False     False            False  33
# 3          False      True            False  32
# 4          False     False            False  31
# ...          ...       ...              ...  ..
# 46063       True     False            False  22
# 46064      False     False             True  21
# 46065      False     False             True  21
# 46066      False     False            False  25
# 46067      False      True            False  24
#
# [46068 rows x 52 columns]
