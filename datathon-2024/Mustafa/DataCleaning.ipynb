# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("cleaned_Test.csv")

# %%
df_new = pd.DataFrame(data = df, columns = ["anne_sektor","baba_sektor"])

# %%
df_new = df_new.replace(['0', '-'], 'Unknown')

# Or alternatively, use NaN and fill later:
# data = data.replace(['0', '-'], pd.NA)

# %%
df_new
# Out:
#       anne_sektor  baba_sektor
# 0     ozel sektor        diger
# 1            kamu         kamu
# 2            kamu         kamu
# 3         Unknown      Unknown
# 4         Unknown      Unknown
# ...           ...          ...
# 9936      Unknown        diger
# 9937      Unknown      Unknown
# 9938      Unknown         kamu
# 9939      Unknown        diger
# 9940      Unknown  ozel sektor
#
# [9941 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Apply label encoding
label_encoder = LabelEncoder()

# Encoding 'anne_sektor' and 'baba_sektor' columns
df_new['anne_sektor_encoded'] = label_encoder.fit_transform(df_new['anne_sektor'])
df_new['baba_sektor_encoded'] = label_encoder.fit_transform(df_new['baba_sektor'])

# %%
df_new = pd.get_dummies(df_new, columns=['anne_sektor', 'baba_sektor'], prefix=['anne', 'baba'], dummy_na=True)

# %%
df_new = df_new.drop(["anne_nan","baba_nan"],axis =1)
df_new
# Out:
#       anne_sektor_encoded  baba_sektor_encoded  anne_Unknown  anne_diger  \
# 0                       3                    1         False       False
# 1                       2                    2         False       False
# 2                       2                    2         False       False
# 3                       0                    0          True       False
# 4                       0                    0          True       False
# ...                   ...                  ...           ...         ...
# 9936                    0                    1          True       False
# 9937                    0                    0          True       False
# 9938                    0                    2          True       False
# 9939                    0                    1          True       False
# 9940                    0                    3          True       False
#
#       anne_kamu  anne_ozel sektor  baba_Unknown  baba_diger  baba_kamu  \
# 0         False              True         False        True      False
# 1          True             False         False       False       True
# 2          True             False         False       False       True
# 3         False             False          True       False      False
# 4         False             False          True       False      False
# ...         ...               ...           ...         ...        ...
# 9936      False             False         False        True      False
# 9937      False             False          True       False      False
# 9938      False             False         False       False       True
# 9939      False             False         False        True      False
# 9940      False             False         False       False      False
#
#       baba_ozel sektor
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 9936             False
# 9937             False
# 9938             False
# 9939             False
# 9940              True
#
# [9941 rows x 10 columns]

# %%
df=df.drop(["anne_sektor","baba_sektor"],axis =1)

# %%
cleanedData = pd.concat([df,df_new],axis = 1)
cleanedData
# Out:
#       basvuru_yili cinsiyet dogum_tarihi dogum_yeri ikametgah_sehri  \
# 0             2023    kadin   2002-06-21     amasya          amasya
# 1             2023    erkek   2002-01-26     samsun        istanbul
# 2             2023    erkek   2003-02-01    isparta           izmir
# 3             2023    erkek   2001-12-01      hatay        kirsehir
# 4             2023    kadin   2000-08-01   adiyaman        adiyaman
# ...            ...      ...          ...        ...             ...
# 9936          2023    kadin   2001-01-19     ankara          ankara
# 9937          2023    kadin   2002-03-01     yozgat          ankara
# 9938          2023    kadin   2001-09-09      konya           konya
# 9939          2023    kadin   2001-10-16   adiyaman        istanbul
# 9940          2023    kadin   1999-09-22      nigde          ankara
#
#                           universite_adi universite_turu  \
# 0                    munzur universitesi          devlet
# 1                  bogazici universitesi          devlet
# 2       izmir yuksek teknoloji enstitusu          devlet
# 3        kirsehir ahi evran universitesi          devlet
# 4        kirsehir ahi evran universitesi          devlet
# ...                                  ...             ...
# 9936              balikesir universitesi          devlet
# 9937                   gazi universitesi          devlet
# 9938  nigde omer halisdemir universitesi          devlet
# 9939           bursa uludag universitesi          devlet
# 9940              hacettepe universitesi          devlet
#
#       burslu_ise_burs_yuzdesi  burs_aliyor_mu?  \
# 0                         0.0                0
# 1                         0.0                0
# 2                         0.0                0
# 3                         0.0                0
# 4                         0.0                0
# ...                       ...              ...
# 9936                      0.0                0
# 9937                      0.0                0
# 9938                      0.0                0
# 9939                      0.0                0
# 9940                      0.0                0
#
#                                                bolum  ... anne_sektor_encoded  \
# 0                                      sosyal hizmet  ...                   3
# 1                                            isletme  ...                   2
# 2                            bilgisayar muhendisligi  ...                   2
# 3                                         hemsirelik  ...                   0
# 4                                     cocuk gelisimi  ...                   0
# ...                                              ...  ...                 ...
# 9936                         bilgisayar muhendisligi  ...                   0
# 9937                           endustri muhendisligi  ...                   0
# 9938                               gida muhendisligi  ...                   0
# 9939  molekuler biyoloji, genetik ve biyomuhendislik  ...                   0
# 9940                           endustri muhendisligi  ...                   0
#
#       baba_sektor_encoded  anne_Unknown anne_diger anne_kamu anne_ozel sektor  \
# 0                       1         False      False     False             True
# 1                       2         False      False      True            False
# 2                       2         False      False      True            False
# 3                       0          True      False     False            False
# 4                       0          True      False     False            False
# ...                   ...           ...        ...       ...              ...
# 9936                    1          True      False     False            False
# 9937                    0          True      False     False            False
# 9938                    2          True      False     False            False
# 9939                    1          True      False     False            False
# 9940                    3          True      False     False            False
#
#      baba_Unknown baba_diger baba_kamu baba_ozel sektor
# 0           False       True     False            False
# 1           False      False      True            False
# 2           False      False      True            False
# 3            True      False     False            False
# 4            True      False     False            False
# ...           ...        ...       ...              ...
# 9936        False       True     False            False
# 9937         True      False     False            False
# 9938        False      False      True            False
# 9939        False       True     False            False
# 9940        False      False     False             True
#
# [9941 rows x 51 columns]

# %%
cleanedData['cinsiyet'] = cleanedData['cinsiyet'].map({'erkek': 0, 'kadin': 1 ,"Belirtmek istemiyorum":-1})

# %%
cleanedData
# Out:
#       basvuru_yili  cinsiyet dogum_tarihi dogum_yeri ikametgah_sehri  \
# 0             2023       1.0   2002-06-21     amasya          amasya
# 1             2023       0.0   2002-01-26     samsun        istanbul
# 2             2023       0.0   2003-02-01    isparta           izmir
# 3             2023       0.0   2001-12-01      hatay        kirsehir
# 4             2023       1.0   2000-08-01   adiyaman        adiyaman
# ...            ...       ...          ...        ...             ...
# 9936          2023       1.0   2001-01-19     ankara          ankara
# 9937          2023       1.0   2002-03-01     yozgat          ankara
# 9938          2023       1.0   2001-09-09      konya           konya
# 9939          2023       1.0   2001-10-16   adiyaman        istanbul
# 9940          2023       1.0   1999-09-22      nigde          ankara
#
#                           universite_adi universite_turu  \
# 0                    munzur universitesi          devlet
# 1                  bogazici universitesi          devlet
# 2       izmir yuksek teknoloji enstitusu          devlet
# 3        kirsehir ahi evran universitesi          devlet
# 4        kirsehir ahi evran universitesi          devlet
# ...                                  ...             ...
# 9936              balikesir universitesi          devlet
# 9937                   gazi universitesi          devlet
# 9938  nigde omer halisdemir universitesi          devlet
# 9939           bursa uludag universitesi          devlet
# 9940              hacettepe universitesi          devlet
#
#       burslu_ise_burs_yuzdesi  burs_aliyor_mu?  \
# 0                         0.0                0
# 1                         0.0                0
# 2                         0.0                0
# 3                         0.0                0
# 4                         0.0                0
# ...                       ...              ...
# 9936                      0.0                0
# 9937                      0.0                0
# 9938                      0.0                0
# 9939                      0.0                0
# 9940                      0.0                0
#
#                                                bolum  ... anne_sektor_encoded  \
# 0                                      sosyal hizmet  ...                   3
# 1                                            isletme  ...                   2
# 2                            bilgisayar muhendisligi  ...                   2
# 3                                         hemsirelik  ...                   0
# 4                                     cocuk gelisimi  ...                   0
# ...                                              ...  ...                 ...
# 9936                         bilgisayar muhendisligi  ...                   0
# 9937                           endustri muhendisligi  ...                   0
# 9938                               gida muhendisligi  ...                   0
# 9939  molekuler biyoloji, genetik ve biyomuhendislik  ...                   0
# 9940                           endustri muhendisligi  ...                   0
#
#       baba_sektor_encoded  anne_Unknown anne_diger anne_kamu anne_ozel sektor  \
# 0                       1         False      False     False             True
# 1                       2         False      False      True            False
# 2                       2         False      False      True            False
# 3                       0          True      False     False            False
# 4                       0          True      False     False            False
# ...                   ...           ...        ...       ...              ...
# 9936                    1          True      False     False            False
# 9937                    0          True      False     False            False
# 9938                    2          True      False     False            False
# 9939                    1          True      False     False            False
# 9940                    3          True      False     False            False
#
#      baba_Unknown baba_diger baba_kamu baba_ozel sektor
# 0           False       True     False            False
# 1           False      False      True            False
# 2           False      False      True            False
# 3            True      False     False            False
# 4            True      False     False            False
# ...           ...        ...       ...              ...
# 9936        False       True     False            False
# 9937         True      False     False            False
# 9938        False      False      True            False
# 9939        False       True     False            False
# 9940        False      False     False             True
#
# [9941 rows x 51 columns]

# %%
cleanedData.to_csv("cleanedData.csv")

# %%
from datetime import datetime

# %%
cleanedData['dogum_tarihi'] = pd.to_datetime(cleanedData['dogum_tarihi'])

# Extract the year of birth
cleanedData['birth_year'] = cleanedData['dogum_tarihi'].dt.year
cleanedData['age'] = 2024 - cleanedData['birth_year']
cleanedData["age"]
# Out:
# 0       22
# 1       22
# 2       21
# 3       23
# 4       24
#         ..
# 9936    23
# 9937    22
# 9938    23
# 9939    23
# 9940    25
# Name: age, Length: 9941, dtype: int32

# %%
cleanedData = cleanedData.drop(["birth_year","dogum_tarihi"],axis =1)

# %%
cleanedData.to_csv("cleanTest.csv")

# %%
list = []
for columns in cleanedData:
    list.append(columns)
list
# Out:
# ['basvuru_yili',
#  'cinsiyet',
#  'dogum_yeri',
#  'ikametgah_sehri',
#  'universite_adi',
#  'universite_turu',
#  'burslu_ise_burs_yuzdesi',
#  'burs_aliyor_mu?',
#  'bolum',
#  'universite_kacinci_sinif',
#  'universite_not_ortalamasi',
#  'daha_once_baska_bir_universiteden_mezun_olmus',
#  'lise_adi',
#  'lise_adi_diger',
#  'lise_sehir',
#  'lise_turu',
#  'lise_bolumu',
#  'lise_bolum_diger',
#  'lise_mezuniyet_notu',
#  'baska_bir_kurumdan_burs_aliyor_mu?',
#  'burs_aldigi_baska_kurum',
#  'baska_kurumdan_aldigi_burs_miktari',
#  'anne_egitim_durumu',
#  'anne_calisma_durumu',
#  'baba_egitim_durumu',
#  'baba_calisma_durumu',
#  'kardes_sayisi',
#  'girisimcilik_kulupleri_tarzi_bir_kulube_uye_misiniz?',
#  'uye_oldugunuz_kulubun_ismi',
#  'profesyonel_bir_spor_daliyla_mesgul_musunuz?',
#  'spor_dalindaki_rolunuz_nedir?',
#  'aktif_olarak_bir_stk_uyesi_misiniz?',
#  "hangi_stk'nin_uyesisiniz?",
#  'stk_projesine_katildiniz_mi?',
#  'girisimcilikle_ilgili_deneyiminiz_var_mi?',
#  'girisimcilikle_ilgili_deneyiminizi_aciklayabilir_misiniz?',
#  'ingilizce_biliyor_musunuz?',
#  'ingilizce_seviyeniz?',
#  'daha_onceden_mezun_olunduysa,_mezun_olunan_universite',
#  'id',
#  'anne_sektor_encoded',
#  'baba_sektor_encoded',
#  'anne_Unknown',
#  'anne_diger',
#  'anne_kamu',
#  'anne_ozel sektor',
#  'baba_Unknown',
#  'baba_diger',
#  'baba_kamu',
#  'baba_ozel sektor',
#  'age']

# %%
cleanedData
# Out:
#       basvuru_yili  cinsiyet dogum_yeri ikametgah_sehri  \
# 0             2023       1.0     amasya          amasya
# 1             2023       0.0     samsun        istanbul
# 2             2023       0.0    isparta           izmir
# 3             2023       0.0      hatay        kirsehir
# 4             2023       1.0   adiyaman        adiyaman
# ...            ...       ...        ...             ...
# 9936          2023       1.0     ankara          ankara
# 9937          2023       1.0     yozgat          ankara
# 9938          2023       1.0      konya           konya
# 9939          2023       1.0   adiyaman        istanbul
# 9940          2023       1.0      nigde          ankara
#
#                           universite_adi universite_turu  \
# 0                    munzur universitesi          devlet
# 1                  bogazici universitesi          devlet
# 2       izmir yuksek teknoloji enstitusu          devlet
# 3        kirsehir ahi evran universitesi          devlet
# 4        kirsehir ahi evran universitesi          devlet
# ...                                  ...             ...
# 9936              balikesir universitesi          devlet
# 9937                   gazi universitesi          devlet
# 9938  nigde omer halisdemir universitesi          devlet
# 9939           bursa uludag universitesi          devlet
# 9940              hacettepe universitesi          devlet
#
#       burslu_ise_burs_yuzdesi  burs_aliyor_mu?  \
# 0                         0.0                0
# 1                         0.0                0
# 2                         0.0                0
# 3                         0.0                0
# 4                         0.0                0
# ...                       ...              ...
# 9936                      0.0                0
# 9937                      0.0                0
# 9938                      0.0                0
# 9939                      0.0                0
# 9940                      0.0                0
#
#                                                bolum universite_kacinci_sinif  \
# 0                                      sosyal hizmet                        1
# 1                                            isletme                        3
# 2                            bilgisayar muhendisligi                        2
# 3                                         hemsirelik                        4
# 4                                     cocuk gelisimi                        4
# ...                                              ...                      ...
# 9936                         bilgisayar muhendisligi                        4
# 9937                           endustri muhendisligi                        2
# 9938                               gida muhendisligi                        3
# 9939  molekuler biyoloji, genetik ve biyomuhendislik                        4
# 9940                           endustri muhendisligi                        4
#
#       ...  baba_sektor_encoded  anne_Unknown anne_diger anne_kamu  \
# 0     ...                    1         False      False     False
# 1     ...                    2         False      False      True
# 2     ...                    2         False      False      True
# 3     ...                    0          True      False     False
# 4     ...                    0          True      False     False
# ...   ...                  ...           ...        ...       ...
# 9936  ...                    1          True      False     False
# 9937  ...                    0          True      False     False
# 9938  ...                    2          True      False     False
# 9939  ...                    1          True      False     False
# 9940  ...                    3          True      False     False
#
#      anne_ozel sektor baba_Unknown baba_diger baba_kamu baba_ozel sektor  age
# 0                True        False       True     False            False   22
# 1               False        False      False      True            False   22
# 2               False        False      False      True            False   21
# 3               False         True      False     False            False   23
# 4               False         True      False     False            False   24
# ...               ...          ...        ...       ...              ...  ...
# 9936            False        False       True     False            False   23
# 9937            False         True      False     False            False   22
# 9938            False        False      False      True            False   23
# 9939            False        False       True     False            False   23
# 9940            False        False      False     False             True   25
#
# [9941 rows x 51 columns]
