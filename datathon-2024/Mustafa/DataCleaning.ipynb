# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("test_clean.csv")

# %%
df_new = pd.DataFrame(data = df, columns = ["anne_sektor","baba_sektor"])

# %%
df_new = df_new.replace(['0', '-'], 'Unknown')

# Or alternatively, use NaN and fill later:
# data = data.replace(['0', '-'], pd.NA)

# %%
df_new
# Out:
#        anne_sektor  baba_sektor
# 0      ozel Sektor        Diger
# 1          Unknown  ozel Sektor
# 2          Unknown      Unknown
# 3          Unknown  ozel Sektor
# 4             Kamu         Kamu
# ...            ...          ...
# 11044      Unknown      Unknown
# 11045      Unknown         Kamu
# 11046      Unknown        Diger
# 11047      Unknown        Diger
# 11048      Unknown  ozel Sektor
#
# [11049 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Apply label encoding
label_encoder = LabelEncoder()

# Encoding 'anne_sektor' and 'baba_sektor' columns
df_new['anne_sektor_encoded'] = label_encoder.fit_transform(df_new['anne_sektor'])
df_new['baba_sektor_encoded'] = label_encoder.fit_transform(df_new['baba_sektor'])

# %%
df_new = pd.get_dummies(df_new, columns=['anne_sektor', 'baba_sektor'], prefix=['anne', 'baba'], dummy_na=True)

# %%
df_new = df_new.drop(["anne_nan","baba_nan"],axis =1)
df_new
# Out:
#        anne_sektor_encoded  baba_sektor_encoded  anne_Diger  anne_Kamu  \
# 0                        3                    0       False      False
# 1                        2                    3       False      False
# 2                        2                    2       False      False
# 3                        2                    3       False      False
# 4                        1                    1       False       True
# ...                    ...                  ...         ...        ...
# 11044                    2                    2       False      False
# 11045                    2                    1       False      False
# 11046                    2                    0       False      False
# 11047                    2                    0       False      False
# 11048                    2                    3       False      False
#
#        anne_Unknown  anne_ozel Sektor  baba_Diger  baba_Kamu  baba_Unknown  \
# 0             False              True        True      False         False
# 1              True             False       False      False         False
# 2              True             False       False      False          True
# 3              True             False       False      False         False
# 4             False             False       False       True         False
# ...             ...               ...         ...        ...           ...
# 11044          True             False       False      False          True
# 11045          True             False       False       True         False
# 11046          True             False        True      False         False
# 11047          True             False        True      False         False
# 11048          True             False       False      False         False
#
#        baba_ozel Sektor
# 0                 False
# 1                  True
# 2                 False
# 3                  True
# 4                 False
# ...                 ...
# 11044             False
# 11045             False
# 11046             False
# 11047             False
# 11048              True
#
# [11049 rows x 10 columns]

# %%
df=df.drop(["anne_sektor","baba_sektor"],axis =1)

# %%
cleanedData = pd.concat([df,df_new],axis = 1)
cleanedData
# Out:
#        basvuru_yili cinsiyet dogum_tarihi dogum_yeri ikametgah_sehri  \
# 0              2023    Kadin   2002-06-21     Amasya          Amasya
# 1              2023    Kadin   2004-11-05      Konya           Konya
# 2              2023    Erkek   2002-04-24   İstanbul        İstanbul
# 3              2023    Erkek   2003-11-03     Mardin          Mardin
# 4              2023    Erkek   2002-01-26     Samsun        İstanbul
# ...             ...      ...          ...        ...             ...
# 11044          2023    Kadin   2002-03-01     Yozgat          Ankara
# 11045          2023    Kadin   2001-09-09      Konya           Konya
# 11046          2023    Erkek   2004-08-06     Ankara          Ankara
# 11047          2023    Kadin   2001-10-16   Adiyaman        İstanbul
# 11048          2023    Kadin   1999-09-22      Nigde          Ankara
#
#                            universite_adi universite_turu  \
# 0                     Munzur universitesi          Devlet
# 1                  Hacettepe universitesi          Devlet
# 2                  Kapadokya universitesi            ozel
# 3             Mardin Artuklu universitesi          Devlet
# 4                   Bogazici universitesi          Devlet
# ...                                   ...             ...
# 11044                   Gazi universitesi          Devlet
# 11045  Nigde omer Halisdemir universitesi          Devlet
# 11046                Karabuk universitesi          Devlet
# 11047           Bursa Uludag universitesi          Devlet
# 11048              Hacettepe universitesi          Devlet
#
#        burslu_ise_burs_yuzdesi burs_aliyor_mu?  \
# 0                          0.0           Hayir
# 1                          0.0           Hayir
# 2                          0.0            Evet
# 3                          0.0           Hayir
# 4                          0.0           Hayir
# ...                        ...             ...
# 11044                      0.0           Hayir
# 11045                      0.0           Hayir
# 11046                      0.0           Hayir
# 11047                      0.0           Hayir
# 11048                      0.0           Hayir
#
#                                                 bolum  ...  \
# 0                                       Sosyal Hizmet  ...
# 1                              Uluslararasi İliskiler  ...
# 2                                               Diger  ...
# 3                                      İslami İlimler  ...
# 4                                             İsletme  ...
# ...                                               ...  ...
# 11044                           Endustri Muhendisligi  ...
# 11045                               Gida Muhendisligi  ...
# 11046                Elektrik-Elektronik Muhendisligi  ...
# 11047  Molekuler Biyoloji, Genetik ve Biyomuhendislik  ...
# 11048                           Endustri Muhendisligi  ...
#
#       anne_sektor_encoded baba_sektor_encoded  anne_Diger anne_Kamu  \
# 0                       3                   0       False     False
# 1                       2                   3       False     False
# 2                       2                   2       False     False
# 3                       2                   3       False     False
# 4                       1                   1       False      True
# ...                   ...                 ...         ...       ...
# 11044                   2                   2       False     False
# 11045                   2                   1       False     False
# 11046                   2                   0       False     False
# 11047                   2                   0       False     False
# 11048                   2                   3       False     False
#
#       anne_Unknown anne_ozel Sektor baba_Diger baba_Kamu baba_Unknown  \
# 0            False             True       True     False        False
# 1             True            False      False     False        False
# 2             True            False      False     False         True
# 3             True            False      False     False        False
# 4            False            False      False      True        False
# ...            ...              ...        ...       ...          ...
# 11044         True            False      False     False         True
# 11045         True            False      False      True        False
# 11046         True            False       True     False        False
# 11047         True            False       True     False        False
# 11048         True            False      False     False        False
#
#       baba_ozel Sektor
# 0                False
# 1                 True
# 2                False
# 3                 True
# 4                False
# ...                ...
# 11044            False
# 11045            False
# 11046            False
# 11047            False
# 11048             True
#
# [11049 rows x 51 columns]

# %%
cleanedData['cinsiyet'] = cleanedData['cinsiyet'].map({'Erkek': 0, 'Kadin': 1 ,"Belirtmek istemiyorum":-1})

# %%
cleanedData
# Out:
#        basvuru_yili  cinsiyet dogum_tarihi dogum_yeri ikametgah_sehri  \
# 0              2023         1   2002-06-21     Amasya          Amasya
# 1              2023         1   2004-11-05      Konya           Konya
# 2              2023         0   2002-04-24   İstanbul        İstanbul
# 3              2023         0   2003-11-03     Mardin          Mardin
# 4              2023         0   2002-01-26     Samsun        İstanbul
# ...             ...       ...          ...        ...             ...
# 11044          2023         1   2002-03-01     Yozgat          Ankara
# 11045          2023         1   2001-09-09      Konya           Konya
# 11046          2023         0   2004-08-06     Ankara          Ankara
# 11047          2023         1   2001-10-16   Adiyaman        İstanbul
# 11048          2023         1   1999-09-22      Nigde          Ankara
#
#                            universite_adi universite_turu  \
# 0                     Munzur universitesi          Devlet
# 1                  Hacettepe universitesi          Devlet
# 2                  Kapadokya universitesi            ozel
# 3             Mardin Artuklu universitesi          Devlet
# 4                   Bogazici universitesi          Devlet
# ...                                   ...             ...
# 11044                   Gazi universitesi          Devlet
# 11045  Nigde omer Halisdemir universitesi          Devlet
# 11046                Karabuk universitesi          Devlet
# 11047           Bursa Uludag universitesi          Devlet
# 11048              Hacettepe universitesi          Devlet
#
#        burslu_ise_burs_yuzdesi burs_aliyor_mu?  \
# 0                          0.0           Hayir
# 1                          0.0           Hayir
# 2                          0.0            Evet
# 3                          0.0           Hayir
# 4                          0.0           Hayir
# ...                        ...             ...
# 11044                      0.0           Hayir
# 11045                      0.0           Hayir
# 11046                      0.0           Hayir
# 11047                      0.0           Hayir
# 11048                      0.0           Hayir
#
#                                                 bolum  ...  \
# 0                                       Sosyal Hizmet  ...
# 1                              Uluslararasi İliskiler  ...
# 2                                               Diger  ...
# 3                                      İslami İlimler  ...
# 4                                             İsletme  ...
# ...                                               ...  ...
# 11044                           Endustri Muhendisligi  ...
# 11045                               Gida Muhendisligi  ...
# 11046                Elektrik-Elektronik Muhendisligi  ...
# 11047  Molekuler Biyoloji, Genetik ve Biyomuhendislik  ...
# 11048                           Endustri Muhendisligi  ...
#
#       anne_sektor_encoded baba_sektor_encoded  anne_Diger anne_Kamu  \
# 0                       3                   0       False     False
# 1                       2                   3       False     False
# 2                       2                   2       False     False
# 3                       2                   3       False     False
# 4                       1                   1       False      True
# ...                   ...                 ...         ...       ...
# 11044                   2                   2       False     False
# 11045                   2                   1       False     False
# 11046                   2                   0       False     False
# 11047                   2                   0       False     False
# 11048                   2                   3       False     False
#
#       anne_Unknown anne_ozel Sektor baba_Diger baba_Kamu baba_Unknown  \
# 0            False             True       True     False        False
# 1             True            False      False     False        False
# 2             True            False      False     False         True
# 3             True            False      False     False        False
# 4            False            False      False      True        False
# ...            ...              ...        ...       ...          ...
# 11044         True            False      False     False         True
# 11045         True            False      False      True        False
# 11046         True            False       True     False        False
# 11047         True            False       True     False        False
# 11048         True            False      False     False        False
#
#       baba_ozel Sektor
# 0                False
# 1                 True
# 2                False
# 3                 True
# 4                False
# ...                ...
# 11044            False
# 11045            False
# 11046            False
# 11047            False
# 11048             True
#
# [11049 rows x 51 columns]

# %%
cleanedData.to_csv("cleanedData.csv")

# %%
from datetime import datetime

# %%
cleanedData['dogum_tarihi'] = pd.to_datetime(cleanedData['dogum_tarihi'])

# Extract the year of birth
cleanedData['birth_year'] = cleanedData['dogum_tarihi'].dt.year
cleanedData['age'] = 2024 - cleanedData['birth_year']
cleanedData["age"]
# Out:
# 0        22
# 1        20
# 2        22
# 3        21
# 4        22
#          ..
# 11044    22
# 11045    23
# 11046    20
# 11047    23
# 11048    25
# Name: age, Length: 11049, dtype: int32

# %%
cleanedData = cleanedData.drop(["birth_year","dogum_tarihi"],axis =1)

# %%
cleanedData.to_csv("cleanedTest.csv")

# %%
list = []
for columns in cleanedData:
    list.append(columns)
list
# Out:
# ['basvuru_yili',
#  'cinsiyet',
#  'dogum_yeri',
#  'ikametgah_sehri',
#  'universite_adi',
#  'universite_turu',
#  'burslu_ise_burs_yuzdesi',
#  'burs_aliyor_mu?',
#  'bolum',
#  'universite_kacinci_sinif',
#  'universite_not_ortalamasi',
#  'daha_once_baska_bir_universiteden_mezun_olmus',
#  'lise_adi',
#  'lise_adi_diger',
#  'lise_sehir',
#  'lise_turu',
#  'lise_bolumu',
#  'lise_bolum_diger',
#  'lise_mezuniyet_notu',
#  'baska_bir_kurumdan_burs_aliyor_mu?',
#  'burs_aldigi_baska_kurum',
#  'baska_kurumdan_aldigi_burs_miktari',
#  'anne_egitim_durumu',
#  'anne_calisma_durumu',
#  'baba_egitim_durumu',
#  'baba_calisma_durumu',
#  'kardes_sayisi',
#  'girisimcilik_kulupleri_tarzi_bir_kulube_uye_misiniz?',
#  'uye_oldugunuz_kulubun_ismi',
#  'profesyonel_bir_spor_daliyla_mesgul_musunuz?',
#  'spor_dalindaki_rolunuz_nedir?',
#  'aktif_olarak_bir_stk_uyesi_misiniz?',
#  "hangi_stk'nin_uyesisiniz?",
#  'stk_projesine_katildiniz_mi?',
#  'girisimcilikle_ilgili_deneyiminiz_var_mi?',
#  'girisimcilikle_ilgili_deneyiminizi_aciklayabilir_misiniz?',
#  'ingilizce_biliyor_musunuz?',
#  'ingilizce_seviyeniz?',
#  'daha_onceden_mezun_olunduysa,_mezun_olunan_universite',
#  'id',
#  'anne_sektor_encoded',
#  'baba_sektor_encoded',
#  'anne_Diger',
#  'anne_Kamu',
#  'anne_Unknown',
#  'anne_ozel Sektor',
#  'baba_Diger',
#  'baba_Kamu',
#  'baba_Unknown',
#  'baba_ozel Sektor',
#  'age']

# %%
cleanedData
# Out:
#        basvuru_yili  cinsiyet dogum_yeri ikametgah_sehri  \
# 0              2023         1     Amasya          Amasya
# 1              2023         1      Konya           Konya
# 2              2023         0   İstanbul        İstanbul
# 3              2023         0     Mardin          Mardin
# 4              2023         0     Samsun        İstanbul
# ...             ...       ...        ...             ...
# 11044          2023         1     Yozgat          Ankara
# 11045          2023         1      Konya           Konya
# 11046          2023         0     Ankara          Ankara
# 11047          2023         1   Adiyaman        İstanbul
# 11048          2023         1      Nigde          Ankara
#
#                            universite_adi universite_turu  \
# 0                     Munzur universitesi          Devlet
# 1                  Hacettepe universitesi          Devlet
# 2                  Kapadokya universitesi            ozel
# 3             Mardin Artuklu universitesi          Devlet
# 4                   Bogazici universitesi          Devlet
# ...                                   ...             ...
# 11044                   Gazi universitesi          Devlet
# 11045  Nigde omer Halisdemir universitesi          Devlet
# 11046                Karabuk universitesi          Devlet
# 11047           Bursa Uludag universitesi          Devlet
# 11048              Hacettepe universitesi          Devlet
#
#        burslu_ise_burs_yuzdesi burs_aliyor_mu?  \
# 0                          0.0           Hayir
# 1                          0.0           Hayir
# 2                          0.0            Evet
# 3                          0.0           Hayir
# 4                          0.0           Hayir
# ...                        ...             ...
# 11044                      0.0           Hayir
# 11045                      0.0           Hayir
# 11046                      0.0           Hayir
# 11047                      0.0           Hayir
# 11048                      0.0           Hayir
#
#                                                 bolum  \
# 0                                       Sosyal Hizmet
# 1                              Uluslararasi İliskiler
# 2                                               Diger
# 3                                      İslami İlimler
# 4                                             İsletme
# ...                                               ...
# 11044                           Endustri Muhendisligi
# 11045                               Gida Muhendisligi
# 11046                Elektrik-Elektronik Muhendisligi
# 11047  Molekuler Biyoloji, Genetik ve Biyomuhendislik
# 11048                           Endustri Muhendisligi
#
#       universite_kacinci_sinif  ... baba_sektor_encoded  anne_Diger anne_Kamu  \
# 0                            1  ...                   0       False     False
# 1                            1  ...                   3       False     False
# 2                            1  ...                   2       False     False
# 3                            1  ...                   3       False     False
# 4                            3  ...                   1       False      True
# ...                        ...  ...                 ...         ...       ...
# 11044                        2  ...                   2       False     False
# 11045                        3  ...                   1       False     False
# 11046                        1  ...                   0       False     False
# 11047                        4  ...                   0       False     False
# 11048                        4  ...                   3       False     False
#
#       anne_Unknown anne_ozel Sektor baba_Diger baba_Kamu baba_Unknown  \
# 0            False             True       True     False        False
# 1             True            False      False     False        False
# 2             True            False      False     False         True
# 3             True            False      False     False        False
# 4            False            False      False      True        False
# ...            ...              ...        ...       ...          ...
# 11044         True            False      False     False         True
# 11045         True            False      False      True        False
# 11046         True            False       True     False        False
# 11047         True            False       True     False        False
# 11048         True            False      False     False        False
#
#       baba_ozel Sektor age
# 0                False  22
# 1                 True  20
# 2                False  22
# 3                 True  21
# 4                False  22
# ...                ...  ..
# 11044            False  22
# 11045            False  23
# 11046            False  20
# 11047            False  23
# 11048             True  25
#
# [11049 rows x 51 columns]
